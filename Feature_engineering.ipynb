# %% [markdown]
# #**Feature engineering**

# %% [markdown]
# **1. What is a parameter?**
# A parameter is a value that defines a model’s behavior and is learned during training (like weights in linear regression).
#
# ---
#
# **2. What is correlation? What does negative correlation mean?**
# Correlation measures the strength and direction of a linear relationship between two variables.
# Negative correlation means that as one variable increases, the other decreases.
#
# ---
#
# **3. Define Machine Learning. What are the main components in Machine Learning?**
# Machine Learning is a field of AI where systems learn patterns from data to make decisions.
# Main components:
#
# * Data
# * Model
# * Loss function
# * Optimizer
# * Evaluation metric
#
# ---
#
# **4. How does loss value help in determining whether the model is good or not?**
# Lower loss value indicates better performance as it shows the difference between predicted and actual values is small.
#
# ---
#
# **5. What are continuous and categorical variables?**
# Continuous variables can take any numeric value within a range (e.g., height).
# Categorical variables take discrete values (e.g., gender, color).
#
# ---
#
# **6. How do we handle categorical variables in Machine Learning? What are the common techniques?**
# We convert them into numerical form.
# Common techniques:
#
# * Label Encoding
# * One-Hot Encoding
# * Ordinal Encoding
#
# ---
#
# **7. What do you mean by training and testing a dataset?**
# Training dataset is used to fit the model.
# Testing dataset is used to evaluate model performance on unseen data.
#
# ---
#
# **8. What is sklearn.preprocessing?**
# It’s a module in Scikit-learn that provides functions for data preprocessing like scaling, encoding, and transforming features.
#
# ---
#
# **9. What is a Test set?**
# A test set is a portion of data used only to evaluate the performance of a trained model.
#
# ---
#
# **10. How do we split data for model fitting (training and testing) in Python? How do you approach a Machine Learning problem?**
# Use `train_test_split()` from `sklearn.model_selection`.
# Approach:
#
# * Understand the problem
# * Collect and clean data
# * Perform EDA
# * Preprocess data
# * Split into train/test
# * Train model
# * Evaluate model
# * Improve and deploy
#
# ---
#
# **11. Why do we have to perform EDA before fitting a model to the data?**
# EDA helps understand the data structure, detect missing values, outliers, and relationships, and informs preprocessing steps.
#
# ---
#
# **12. What is correlation?**
# Correlation is a statistical measure that describes the strength and direction of a linear relationship between two variables.
#
# ---
#
# **13. What does negative correlation mean?**
# Negative correlation means that as one variable increases, the other tends to decrease.
#
# ---
#
# **14. How can you find correlation between variables in Python?**
# Use `.corr()` method in pandas:
#
# ```python
# df.corr()
# ```
#
# ---
#
# **15. What is causation? Explain difference between correlation and causation with an example.**
# Causation means one variable directly affects another.
# **Difference:**
#
# * Correlation: Ice cream sales and drowning cases rise together (due to summer).
# * Causation: Smoking causes lung disease.
#
# ---
#
# **16. What is an Optimizer? What are different types of optimizers? Explain each with an example.**
# An optimizer updates model parameters to minimize loss.
# Common types:
#
# * **SGD (Stochastic Gradient Descent)**: Updates weights after each sample.
# * **Adam**: Combines momentum and RMSProp for adaptive learning rate.
#   Example with Keras:
#
# ```python
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
# ```
#
# ---
#
# **17. What is sklearn.linear\_model?**
# A module in Scikit-learn that contains linear models like LinearRegression, LogisticRegression, Ridge, etc.
#
# ---
#
# **18. What does model.fit() do? What arguments must be given?**
# `model.fit()` trains the model using training data.
# Arguments: `X_train`, `y_train`
#
# ```python
# model.fit(X_train, y_train)
# ```
#
# ---
#
# **19. What does model.predict() do? What arguments must be given?**
# `model.predict()` makes predictions on new data.
# Argument: `X_test`
#
# ```python
# model.predict(X_test)
# ```
#
# ---
#
# **20. What are continuous and categorical variables?**
# Already answered in Q5. Repeated question.
#
# ---
#
# **21. What is feature scaling? How does it help in Machine Learning?**
# Feature scaling normalizes data to a specific range or distribution.
# It improves convergence speed and accuracy, especially for distance-based models.
#
# ---
#
# **22. How do we perform scaling in Python?**
# Using `StandardScaler` or `MinMaxScaler` from `sklearn.preprocessing`:
#
# ```python
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# ```
#
# ---
#
# **23. What is sklearn.preprocessing?**
# Already answered in Q8. Repeated question.
#
# ---
#
# **24. How do we split data for model fitting (training and testing) in Python?**
# Use `train_test_split` from `sklearn.model_selection`:
#
# ```python
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# ```
#
# ---
#
# **25. Explain data encoding?**
# Data encoding is the process of converting categorical data into numeric format so that it can be used by ML models.
# Examples:
#
# * **Label Encoding:** Converts categories to integers.
# * **One-Hot Encoding:** Creates binary columns for each category.
#
# ```python
# from sklearn.preprocessing import OneHotEncoder
# ohe = OneHotEncoder()
# X_encoded = ohe.fit_transform(X)
# ```
#
# ---
#
# Let me know if you want this as a PDF/Word file or need examples for any question.
